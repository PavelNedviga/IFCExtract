# %%
import pandas as pd
# Out:
# /var/folders/rn/rl1dzql55sd8tt1fhxq5dlzm0000gn/T/ipykernel_54543/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('Assignment-2_Data.csv')
df.describe()
# Out:
#                  Id           age        balance           day      duration  \
# count  45211.000000  45199.000000   45208.000000  45211.000000  45211.000000
# mean   23606.000000     40.933627    1362.346620     15.806419    258.163080
# std    13051.435847     10.623149    3044.852387      8.322476    257.527812
# min     1001.000000     -1.000000   -8019.000000      1.000000      0.000000
# 25%    12303.500000     33.000000      72.000000      8.000000    103.000000
# 50%    23606.000000     39.000000     448.000000     16.000000    180.000000
# 75%    34908.500000     48.000000    1428.000000     21.000000    319.000000
# max    46211.000000     95.000000  102127.000000     31.000000   4918.000000
#
#            campaign         pdays      previous
# count  45211.000000  45211.000000  45211.000000
# mean       2.763841     40.197828      0.580323
# std        3.098021    100.128746      2.303441
# min        1.000000     -1.000000      0.000000
# ...

# %%
df.age.value_counts().sort_index(axis = 0) # Определить частотность
# Out:
# age
# -1.0      3
#  18.0    12
#  19.0    35
#  20.0    50
#  21.0    79
#          ..
#  90.0     2
#  92.0     2
#  93.0     2
#  94.0     1
#  95.0     2
# Name: count, Length: 78, dtype: int64

# %%
df.loc[df.age.isna(),:] # искать пропуски
# Out:
#       Id  age           job   marital  education default  balance housing  \
# 0   1001  NaN    management   married   tertiary      no   2143.0     yes
# 1   1002  NaN           NaN    single  secondary      no     29.0     yes
# 2   1003  NaN  entrepreneur   married  secondary      no      2.0     yes
# 7   1008  NaN  entrepreneur  divorced   tertiary     yes      NaN     yes
# 53  1054  NaN        admin.    single  secondary      no    -76.0     yes
# 54  1055  NaN    technician    single  secondary      no   -103.0     yes
# 55  1056  NaN  entrepreneur    single   tertiary      no    243.0      no
# 56  1057  NaN    management    single   tertiary      no    424.0     yes
# 57  1058  NaN   blue-collar   married    unknown      no    306.0     yes
# 58  1059  NaN   blue-collar    single    unknown      no     24.0     yes
# 59  1060  NaN      services   married    primary      no    179.0     yes
# 60  1061  NaN        admin.   married   tertiary      no      0.0     yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         45211 non-null  int64
#  1   age        45199 non-null  float64
#  2   job        45210 non-null  object
#  3   marital    45211 non-null  object
#  4   education  45211 non-null  object
#  5   default    45211 non-null  object
#  6   balance    45208 non-null  float64
#  7   housing    45211 non-null  object
#  8   loan       45211 non-null  object
#  9   contact    45211 non-null  object
#  10  day        45211 non-null  int64
#  11  month      45211 non-null  object
#  12  duration   45211 non-null  int64
#  13  campaign   45211 non-null  int64
#  14  pdays      45211 non-null  int64
#  15  previous   45211 non-null  int64
#  16  poutcome   45211 non-null  object
#  17  y          45211 non-null  object
# dtypes: float64(2), int64(6), object(10)
# memory usage: 6.2+ MB

# %%
df.loc[df.age.duplicated() != True,:]
# Out:
#           Id   age          job   marital education default  balance housing  \
# 0       1001   NaN   management   married  tertiary      no   2143.0     yes
# 3       1004  47.0  blue-collar   married   unknown      no   1506.0     yes
# 4       1005  33.0      unknown    single   unknown      no      1.0      no
# 5       1006  35.0   management   married  tertiary      no    231.0     yes
# 6       1007  28.0   management    single  tertiary      no    447.0     yes
# ...      ...   ...          ...       ...       ...     ...      ...     ...
# 41923  42924  87.0      retired  divorced   primary      no   6746.0      no
# 41934  42935  92.0      retired   married   unknown      no    775.0      no
# 44262  45263  93.0      retired   married   unknown      no    775.0      no
# 44669  45670  88.0      retired   married   primary      no    648.0      no
# 45203  46204  -1.0      student    single  tertiary      no    113.0      no
#
# ...

# %%
df.job.unique()
# Out:
# array(['management', nan, 'entrepreneur', 'blue-collar', 'unknown',
#        'retired', 'technician', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
df.pivot_table(index=['marital', 'job'], columns='education', values='balance', aggfunc='sum')
# Out:
# education                 primary  secondary   tertiary   unknown
# marital  job
# divorced admin.           35785.0   560356.0    43770.0   18839.0
#          blue-collar     282285.0   287802.0    16595.0   28923.0
#          entrepreneur      3736.0    49217.0   142834.0   11132.0
#          housemaid       112587.0   107301.0    49379.0   20206.0
#          management       38360.0   109258.0  1597709.0   52353.0
#          retired         263949.0   228326.0   121431.0   27124.0
#          self-employed    15754.0    72202.0   251705.0      28.0
#          services         54146.0   354684.0    15630.0   33573.0
#          student           2755.0      422.0     3046.0     383.0
#          technician       24783.0   567716.0   226462.0   35784.0
#          unemployed       13062.0   198094.0    28805.0    1088.0
#          unknown           8334.0     5927.0     4681.0   10065.0
# married  admin.          142044.0  2818267.0   261125.0  229400.0
# ...

# %%
import seaborn as sns 
sns.heatmap(df.pivot_table(index=['marital', 'job'], columns='education', values='balance', aggfunc='sum'))
# Out:
# <Axes: xlabel='education', ylabel='marital-job'>

# %%
df.sample(10)
# Out:
#           Id   age            job   marital  education default  balance  \
# 18308  19309  47.0     management   married    unknown      no   4567.0
# 37538  38539  32.0       services    single  secondary      no    385.0
# 31528  32529  48.0         admin.  divorced  secondary      no   4099.0
# 21958  22959  48.0       services   married  secondary      no    109.0
# 34384  35385  33.0     management   married   tertiary      no  17946.0
# 10689  11690  40.0       services   married    unknown      no   4075.0
# 6740    7741  45.0    blue-collar   married    unknown      no   -320.0
# 25969  26970  56.0         admin.   married  secondary      no      0.0
# 13888  14889  58.0  self-employed   married  secondary      no   9994.0
# 1168    2169  34.0     management   married    primary      no      6.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# 18308      no   no  telephone   31   jul       921         4     -1         0
# ...

# %%
import numpy as np
from sklearn import preprocessing
X_train = np.array([[ 1., -1.,  2.],
                    [ 2.,  0.,  0.],
                    [ 0.,  1., -1.]])
min_max_scaler = preprocessing.MinMaxScaler()
X_train_minmax = min_max_scaler.fit_transform(X_train)
X_train_minmax
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 2
#       1 import numpy as np
# ----> 2 from sklearn import preprocessing
#       3 X_train = np.array([[ 1., -1.,  2.],
#       4                     [ 2.,  0.,  0.],
#       5                     [ 0.,  1., -1.]])
#       6 min_max_scaler = preprocessing.MinMaxScaler()
#
# ModuleNotFoundError: No module named 'sklearn'
